# %%
import json
import psycopg2
from psycopg2.extras import execute_values
import os
import uuid
import pandas as pd
from datetime import datetime

# %%
conn_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "postgres",
    "host": "localhost",
    "port": 5432
}

create_table_statements = {
    "users": """
        CREATE TABLE IF NOT EXISTS users (
            user_id UUID PRIMARY KEY,
            active BOOLEAN,
            created_date TIMESTAMP,
            last_login TIMESTAMP,
            role VARCHAR(255),
            sign_up_source VARCHAR(255),
            state VARCHAR(255)
        );
    """,
    "brands": """
        CREATE TABLE IF NOT EXISTS brands (
            brand_id UUID PRIMARY KEY,
            name VARCHAR(255),
            category VARCHAR(255),
            barcode VARCHAR(255),
            brand_code VARCHAR(255) UNIQUE,
            cpg_id UUID,
            top_brand BOOLEAN,
            category_code VARCHAR(255)
        );
    """,
    "receipts": """
        CREATE TABLE IF NOT EXISTS receipts (
            receipt_id UUID PRIMARY KEY,
            bonus_points_earned INT,
            bonus_points_earned_reason VARCHAR(255),
            create_date TIMESTAMP,
            date_scanned TIMESTAMP,
            finished_date TIMESTAMP,
            modify_date TIMESTAMP,
            points_awarded_date TIMESTAMP,
            points_earned DECIMAL(10,2),
            purchase_date DATE,
            purchased_item_count INT,
            rewards_receipt_status VARCHAR(50),
            total_spent DECIMAL(10, 2),
            user_id UUID REFERENCES users(user_id)
        );
    """
}

# %%
def create_tables():
    try:
        conn = psycopg2.connect(**conn_params)
        cur = conn.cursor()
        for table_name, create_statement in create_table_statements.items():
            cur.execute(create_statement)
            print(f"Table {table_name} is created successfully.")
        conn.commit()
        cur.close()
        conn.close()
    except Exception as e:
        print(f"Error creating tables: {e}")

# %%
create_tables()
# Out:
# Table users is created successfully.
# Table brands is created successfully.
# Table receipts is created successfully.

# %%
def convert_to_timestamp(ms):
    return datetime.utcfromtimestamp(ms / 1000.0) if ms is not None else None

def get_nested_value(record, keys):
    value = record
    for key in keys:
        if key in ["pointsEarned","total_spent"]:
            return float(value.get(key,0))
        if isinstance(value, dict):
            value = value.get(key)
        else:
            return None
    return value

def convert_to_valid_uuid(value):
    try:
        if len(value) == 32:
            return str(uuid.UUID(value))
        elif len(value) < 32:
            value = value.ljust(32, '0')  # Pad with zeros to make it 32 characters long
            return str(uuid.UUID(value))
        else:
            raise ValueError("The value is too long to be a UUID.")
    except ValueError as e:
        print(f"Error converting to UUID: {e}")
        return None

def load_json_lines_to_table(json_file, table_name, columns, column_mappings):
    records = []
    
    with open(json_file, 'r') as file:
        for line in file:
            try:
                record = json.loads(line.strip())
                processed_record = []
                for col in columns:
                    value = get_nested_value(record, column_mappings[col])
                    # print(type(value))
                    if isinstance(value, dict) and "$oid" in value:
                        value = value["$oid"]
                    elif isinstance(value, dict) and "$date" in value:
                        value = convert_to_timestamp(value["$date"])
                    if col.endswith("_id") and value or (col.endswith("userId")):
                        value = convert_to_valid_uuid(value)
                    processed_record.append(value)
                
                records.append(tuple(processed_record))
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON from line: {line}")
                print(e)

    print(table_name+str(len(records)))

    if records:
        for record in records:
            query = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({', '.join(['%s'] * len(columns))})"
            try:
                conn = psycopg2.connect(**conn_params)
                cur = conn.cursor()
                cur.execute(query, record)
                conn.commit()
                cur.close()
                conn.close()
            except Exception as e:
                print(f"Error inserting data into table {table_name}: {e}")


column_mappings_users = {
    'user_id': ['_id'],
    'active': ['active'],
    'created_date': ['createdDate'],
    'last_login': ['lastLogin'],
    'role': ['role'],
    'sign_up_source': ['signUpSource'],
    'state': ['state']
}

column_mappings_brands = {
    'brand_id': ['_id'],
    'name': ['name'],
    'category': ['category'],
    'barcode': ['barcode'],
    'brand_code': ['brandCode'],
    'cpg_id': ['cpg', '$id'],
    'top_brand': ['topBrand'],
    'category_code': ['categoryCode']
}

column_mappings_receipts = {
    'receipt_id': ['_id'],
    'bonus_points_earned': ['bonusPointsEarned'],
    'bonus_points_earned_reason': ['bonusPointsEarnedReason'],
    'create_date': ['createDate'],
    'date_scanned': ['dateScanned'],
    'finished_date': ['finishedDate'],
    'modify_date': ['modifyDate'],
    'points_awarded_date': ['pointsAwardedDate'],
    'points_earned': ['pointsEarned'],
    'purchase_date': ['purchaseDate'],
    'purchased_item_count': ['purchasedItemCount'],
    'rewards_receipt_status': ['rewardsReceiptStatus'],
    'total_spent': ['totalSpent'],
    'user_id': ['userId']
}

# %%
print(convert_to_valid_uuid("5ff1e1bb0a720f052300056b"))
# Out:
# 5ff1e1bb-0a72-0f05-2300-056b00000000

# %%
record.get('createdDate')
# Out:
# {'$date': 1418998882381}

# %%
conn_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "postgres",
    "host": "localhost",
    "port": 5432
}

# SQL statements to create tables
create_table_statements = {
    "users": """
        CREATE TABLE IF NOT EXISTS users (
            user_id UUID PRIMARY KEY,
            active BOOLEAN,
            created_date TIMESTAMP,
            last_login TIMESTAMP,
            role VARCHAR(50),
            sign_up_source VARCHAR(50),
            state VARCHAR(2)
        );
    """,
    "brands": """
        CREATE TABLE IF NOT EXISTS brands (
            brand_id UUID PRIMARY KEY,
            name VARCHAR(255),
            category VARCHAR(255),
            barcode VARCHAR(255),
            brand_code VARCHAR(255) UNIQUE,
            cpg_id UUID,
            top_brand BOOLEAN,
            category_code VARCHAR(255)
        );
    """,
    "receipts": """
        CREATE TABLE IF NOT EXISTS receipts (
            receipt_id UUID PRIMARY KEY,
            bonus_points_earned INT,
            bonus_points_earned_reason VARCHAR(255),
            create_date TIMESTAMP,
            date_scanned TIMESTAMP,
            finished_date TIMESTAMP,
            modify_date TIMESTAMP,
            points_awarded_date TIMESTAMP,
            points_earned NUMERIC(10, 2),
            purchase_date TIMESTAMP,
            purchased_item_count INT,
            rewards_receipt_status VARCHAR(50),
            total_spent NUMERIC(10, 2),
            user_id UUID REFERENCES users(user_id)
        );
    """,
    "cpg": """
        CREATE TABLE IF NOT EXISTS cpg (
            cpg_id UUID PRIMARY KEY,
            name VARCHAR(255)
        );
    """,
    "receipt_items": """
        CREATE TABLE IF NOT EXISTS receipt_items (
            receipt_item_id UUID PRIMARY KEY,
            receipt_id UUID REFERENCES receipts(receipt_id),
            barcode VARCHAR(255),
            brand_code VARCHAR(255) REFERENCES brands(brand_code) ,
            description VARCHAR(255),
            discounted_item_price NUMERIC(10, 2),
            final_price NUMERIC(10, 2),
            item_price NUMERIC(10, 2),
            needs_fetch_review BOOLEAN,
            needs_fetch_review_reason VARCHAR(255),
            original_receipt_item_text TEXT,
            partner_item_id UUID,
            points_earned INT,
            points_payer_id UUID,
            price_after_coupon NUMERIC(10, 2),
            prevent_target_gap_points BOOLEAN,
            quantity_purchased INT,
            rewards_group VARCHAR(255),
            rewards_product_partner_id UUID,
            target_price NUMERIC(10, 2),
            user_flagged_barcode VARCHAR(255),
            user_flagged_description VARCHAR(255),
            user_flagged_new_item BOOLEAN,
            user_flagged_price NUMERIC(10, 2),
            user_flagged_quantity INT
        );
    """
}

# %%
create_tables()
# Out:
# Table users is created successfully.
# Table brands is created successfully.
# Table receipts is created successfully.
# Table cpg is created successfully.
# Table receipt_items is created successfully.

# %%
# Define column mappings to handle nested fields
column_mappings_users = {
    'user_id': ['_id', '$oid'],
    'active': ['active'],
    'created_date': ['createdDate', '$date'],
    'last_login': ['lastLogin', '$date'],
    'role': ['role'],
    'sign_up_source': ['signUpSource'],
    'state': ['state']
}

column_mappings_brands = {
    'brand_id': ['_id', '$oid'],
    'name': ['name'],
    'category': ['category'],
    'barcode': ['barcode'],
    'brand_code': ['brandCode'],
    'cpg_id': ['cpg', '$id', '$oid'],
    'top_brand': ['topBrand'],
    'category_code': ['categoryCode']
}

column_mappings_receipts = {
    'receipt_id': ['_id', '$oid'],
    'bonus_points_earned': ['bonusPointsEarned'],
    'bonus_points_earned_reason': ['bonusPointsEarnedReason'],
    'create_date': ['createDate', '$date'],
    'date_scanned': ['dateScanned', '$date'],
    'finished_date': ['finishedDate', '$date'],
    'modify_date': ['modifyDate', '$date'],
    'points_awarded_date': ['pointsAwardedDate', '$date'],
    'points_earned': ['pointsEarned'],
    'purchase_date': ['purchaseDate', '$date'],
    'purchased_item_count': ['purchasedItemCount'],
    'rewards_receipt_status': ['rewardsReceiptStatus'],
    'total_spent': ['totalSpent'],
    'user_id': ['userId']
}

column_mappings_receipt_items = {
    'receipt_item_id': [],
    'receipt_id': [],
    'barcode': ['barcode'],
    'brand_code':['brandCode'],
    'description': ['description'],
    'discounted_item_price': ['discountedItemPrice'],
    'final_price': ['finalPrice'],
    'item_price': ['itemPrice'],
    'needs_fetch_review': ['needsFetchReview'],
    'needs_fetch_review_reason': ['needsFetchReviewReason'],
    'original_receipt_item_text': ['originalReceiptItemText'],
    'partner_item_id': ['partnerItemId', '$oid'],
    'points_earned': ['pointsEarned'],
    'points_payer_id': ['pointsPayerId', '$oid'],
    'price_after_coupon': ['priceAfterCoupon'],
    'prevent_target_gap_points': ['preventTargetGapPoints'],
    'quantity_purchased': ['quantityPurchased'],
    'rewards_group': ['rewardsGroup'],
    'rewards_product_partner_id': ['rewardsProductPartnerId', '$oid'],
    'target_price': ['targetPrice'],
    'user_flagged_barcode': ['userFlaggedBarcode'],
    'user_flagged_description': ['userFlaggedDescription'],
    'user_flagged_new_item': ['userFlaggedNewItem'],
    'user_flagged_price': ['userFlaggedPrice'],
    'user_flagged_quantity': ['userFlaggedQuantity']
}

# %%
def convert_to_timestamp(ms):
    return datetime.utcfromtimestamp(ms / 1000.0) if ms is not None else None

def get_nested_value(record, keys):
    try:
        value = record
        for key in keys:
            if key in ["pointsEarned","total_spent","discounted_item_price","final_price","item_price","price_after_coupon","target_price","user_flagged_price"]:
                return float(value.get(key,0))
            if key in ["$date"]:
                value = convert_to_timestamp(value["$date"])
                return value
            if isinstance(value, dict):
                value = value.get(key)
            else:
                return None
        return value
    except Exception as e:
        return None

def convert_to_valid_uuid(value):
    try:
        if len(value) == 32:
            return str(uuid.UUID(value))
        elif len(value) < 32:
            value = value.ljust(32, '0')  # Pad with zeros to make it 32 characters long
            return str(uuid.UUID(value))
        else:
            raise ValueError("The value is too long to be a UUID.")
    except ValueError as e:
        # print(f"Error converting to UUID: {e}")
        return uuid.uuid4()


def load_json_lines_to_table(json_file, table_name, columns, column_mappings):
    with open(json_file, 'r') as file:
        for line in file:
            try:
                record = json.loads(line.strip())
                processed_record = []
                for col in columns:
                    value = get_nested_value(record, column_mappings[col])
                    if col.endswith("_id") and value:
                        value = convert_to_valid_uuid(value)
                    processed_record.append(value)

                query = f"INSERT INTO {table_name} ({', '.join(columns)}) VALUES ({', '.join(['%s'] * len(columns))})"
                conn = psycopg2.connect(**conn_params)
                cur = conn.cursor()
                cur.execute(query, processed_record)
                conn.commit()
                cur.close()
                conn.close()
            except Exception as e:
                print(f"Error inserting data into table {table_name}: {e}")



# Load brands next
def load_brands_and_cpg(json_file):
    with open(json_file, 'r') as file:
        cpg_records = set()
        for line in file:
            try:
                record = json.loads(line.strip())
                cpg_record = get_nested_value(record, ['cpg'])
                if cpg_record:
                    cpg_id = convert_to_valid_uuid(cpg_record.get('$id', {}).get('$oid', None))
                    cpg_name = cpg_record.get('name')
                    cpg_records.add((cpg_id, cpg_name))
                processed_record = []
                for col in column_mappings_brands:
                    value = get_nested_value(record, column_mappings_brands[col])
                    if col.endswith("_id") and value:
                        value = convert_to_valid_uuid(value)
                    processed_record.append(value)

                query = f"INSERT INTO brands ({', '.join(column_mappings_brands.keys())}) VALUES ({', '.join(['%s'] * len(column_mappings_brands))})"
                conn = psycopg2.connect(**conn_params)
                cur = conn.cursor()
                cur.execute(query, processed_record)
                conn.commit()
                cur.close()
                conn.close()
            except Exception as e:
                print(f"Error inserting data into table brands: {e}")

        # Insert CPG records
        if cpg_records:
            cpg_query = "INSERT INTO cpg (cpg_id, name) VALUES %s ON CONFLICT DO NOTHING"
            try:
                conn = psycopg2.connect(**conn_params)
                cur = conn.cursor()
                execute_values(cur, cpg_query, list(cpg_records))
                conn.commit()
                cur.close()
                conn.close()
            except Exception as e:
                print(f"Error inserting data into table cpg: {e}")




def load_receipts_and_items(json_file):
    with open(json_file, 'r') as file:
        for line in file:
            try:
                record = json.loads(line.strip())
                receipt_items_records = []
                receipt_items = record.get('rewardsReceiptItemList', [])
                receipt_id = convert_to_valid_uuid(record.get('_id', {}).get('$oid', None))
                for item in receipt_items:
                    receipt_item_record = [str(uuid.uuid4()), receipt_id]  # Generate a new UUID for receipt_item_id and set receipt_id
                    for col in column_mappings_receipt_items:
                        print(col)
                        if col not in ['receipt_item_id', 'receipt_id']:
                            value = get_nested_value(item, column_mappings_receipt_items[col])
                            if col.endswith("_id") and value:
                                value = convert_to_valid_uuid(value)
                            receipt_item_record.append(value)
                    receipt_items_records.append(receipt_item_record)

                processed_record = []
                for col in column_mappings_receipts:
                    value = get_nested_value(record, column_mappings_receipts[col])
                    if col.endswith("_id") and value:
                        value = convert_to_valid_uuid(value)
                    processed_record.append(value)
            except Exception as e:
                print(f"Error handling data into table receipts or receipt_items: {e}")
            try:
                print(len(processed_record))

                receipt_query = f"INSERT INTO receipts ({', '.join(column_mappings_receipts.keys())}) VALUES ({', '.join(['%s'] * len(column_mappings_receipts))})"
                conn = psycopg2.connect(**conn_params)
                cur = conn.cursor()
                cur.execute(receipt_query, processed_record)
                conn.commit()
                
                # Insert receipt items
                if receipt_items_records:
                    receipt_items_query = f"INSERT INTO receipt_items ({', '.join(['receipt_item_id', 'receipt_id'] + [col for col in column_mappings_receipt_items if col not in ['receipt_item_id', 'receipt_id']])}) VALUES %s"
                    execute_values(cur, receipt_items_query, receipt_items_records)
                    conn.commit()
                
                cur.close()
                conn.close()
            except Exception as e:
                print(f"Error inserting data into table receipts or receipt_items: {e}")

# %%
with open("../../0.data/receipts.json", 'r') as file:
        for line in file:
            try:
                record = json.loads(line.strip())
                receipt_items_records = []
                receipt_items = record.get('rewardsReceiptItemList', [])
                receipt_id = convert_to_valid_uuid(record.get('_id', {}).get('$oid', None))
                for item in receipt_items:
                    receipt_item_record = [str(uuid.uuid4()), receipt_id]  # Generate a new UUID for receipt_item_id and set receipt_id
                    for col in column_mappings_receipt_items:
                        print(col)
                        if col not in ['receipt_item_id', 'receipt_id']:
                            value = get_nested_value(item, column_mappings_receipt_items[col])
                            if col.endswith("_id") and value:
                                value = convert_to_valid_uuid(value)
                            receipt_item_record.append(value)
                    receipt_items_records.append(receipt_item_record)
                processed_record = []
                for col in column_mappings_receipts:
                    value = get_nested_value(record, column_mappings_receipts[col])
                    # if col.endswith("_id") and value:
                    #     value = convert_to_valid_uuid(value)
                    processed_record.append(value)
            except Exception as e:
                print(record)
                print(f"Error handling data into table receipts or receipt_items: {e}")
            try:
                print(len(processed_record))

                receipt_query = f"INSERT INTO receipts ({', '.join(columns)}) VALUES ({', '.join(['%s'] * len(columns))})"
                conn = psycopg2.connect(**conn_params)
                cur = conn.cursor()
                cur.execute(receipt_query, processed_record)
                conn.commit()
                print(receipt_items_records)
            except Exception as e:            
                print(f"Error inserting data into table receipts: {e}")
            try:
                
                # Insert receipt items
                if receipt_items_records:
                    receipt_items_query = f"INSERT INTO receipt_items ({', '.join(['receipt_item_id', 'receipt_id'] + [col for col in column_mappings_receipt_items if col not in ['receipt_item_id', 'receipt_id']])}) VALUES %s"
                    execute_values(cur, receipt_items_query, receipt_items_records)
                    conn.commit()
                
                cur.close()
                conn.close()
            except Exception as e:
                print(f"Error inserting data into table receipts: {e}")
# Out:
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1eb-0a72-0f05-2300-057500000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1bb-0a72-0f05-2300-056b00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1f1-0a72-0f05-2300-057a00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1ee-0a72-14ad-a100-056f00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1d2-0a72-14ad-a100-056100000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1e4-0a72-14ad-a100-056600000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1cd-0a72-0f05-2300-056f00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# /var/folders/dl/nq7zpgs52r382_fm_jd2ygyh0000gn/T/ipykernel_40017/1324348814.py:2: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return datetime.utcfromtimestamp(ms / 1000.0) if ms is not None else None
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1a4-0a72-0f05-2300-056900000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1ed-0a72-14ad-a100-056e00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1eb-0a72-14ad-a100-056b00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1c5-0a72-0f05-2300-056c00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1a1-0a72-0f05-2300-056800000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1b6-0a72-14ad-a100-055c00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5f9c74f7-0a72-14ad-0700-003700000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1b2-0a72-14ad-a100-055a00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1e9-0a72-14ad-a100-056900000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1df-0a72-14ad-a100-056400000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1b4-0a72-14ad-a100-055b00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1eb-0a72-0f05-2300-057600000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1c8-0a72-0f05-2300-056d00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5f9c74f9-0a72-14ad-0700-003800000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e196-0a72-0f05-2300-056700000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1ec-0a72-14ad-a100-056c00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1d7-0a72-0f05-2300-057100000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1c6-0a72-14ad-a100-055e00000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1ee-0a72-14ad-a100-057000000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1cf-0a72-0f05-2300-057000000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1e1-0a72-0f05-2300-057200000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1d4-0a72-14ad-a100-056200000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff1e1ee-0a72-0f05-2300-057800000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff37103-0a72-14ad-a100-05a500000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14
# Error inserting data into table receipts: not all arguments converted during string formatting
# Error inserting data into table receipts: insert or update on table "receipt_items" violates foreign key constraint "receipt_items_receipt_id_fkey"
# DETAIL:  Key (receipt_id)=(5ff36dcc-0a72-0f05-2300-05b100000000) is not present in table "receipts".
#
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# ...
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# receipt_item_id
# receipt_id
# barcode
# description
# discounted_item_price
# final_price
# item_price
# needs_fetch_review
# needs_fetch_review_reason
# original_receipt_item_text
# partner_item_id
# points_earned
# points_payer_id
# price_after_coupon
# prevent_target_gap_points
# quantity_purchased
# rewards_group
# rewards_product_partner_id
# target_price
# user_flagged_barcode
# user_flagged_description
# user_flagged_new_item
# user_flagged_price
# user_flagged_quantity
# 14

# %%
receipt_items
# Out:
# []

# %%
# Load users first
load_json_lines_to_table('../../0.data/users.json', 'users', [
    'user_id', 'active', 'created_date', 'last_login', 'role', 'sign_up_source', 'state'
], column_mappings_users)
# Out:
# /var/folders/dl/nq7zpgs52r382_fm_jd2ygyh0000gn/T/ipykernel_40017/4108846935.py:2: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return datetime.utcfromtimestamp(ms / 1000.0) if ms is not None else None
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e1ea-cfcf-6c39-9c27-4ae600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e1ea-cfcf-6c39-9c27-4ae600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e1ea-cfcf-6c39-9c27-4ae600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff1e194-b6a9-d73a-3a9f-105200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff370c5-62fd-e912-123a-5e0e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36d03-62fd-e912-123a-553500000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36be7-135e-7011-bcb8-56d300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36d03-62fd-e912-123a-553500000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36a38-62fd-e912-123a-446000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff370c5-62fd-e912-123a-5e0e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36a38-62fd-e912-123a-446000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36a38-62fd-e912-123a-446000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff370c5-62fd-e912-123a-5e0e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36a38-62fd-e912-123a-446000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff370c5-62fd-e912-123a-5e0e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff36be7-135e-7011-bcb8-56d300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff47392-c3d6-3511-e2a4-788100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce33-c3d6-3511-e2a4-84b600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff47392-c3d6-3511-e2a4-788100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce33-c3d6-3511-e2a4-84b600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce3d-c3d6-3511-e2a4-84dc00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce33-c3d6-3511-e2a4-84b600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff47392-c3d6-3511-e2a4-788100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce3d-c3d6-3511-e2a4-84dc00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce3d-c3d6-3511-e2a4-84dc00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce33-c3d6-3511-e2a4-84b600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce33-c3d6-3511-e2a4-84b600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff4ce33-c3d6-3511-e2a4-84b600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff47392-c3d6-3511-e2a4-788100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff5d15a-eb7c-7d12-096d-91a200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff7264e-8f14-2f11-dd18-950400000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff7268e-eb7c-7d12-096d-a2a900000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff7264e-8f14-2f11-dd18-950400000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff7930f-b334-8b11-c933-72a600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff73b90-eb7c-7d31-ca8a-452b00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff7264e-8f14-2f11-dd18-950400000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff7930f-b334-8b11-c933-72a600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff8ce85-0492-9111-f6e9-13cb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff873d1-b334-8b11-c933-771600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff873d1-b334-8b11-c933-771600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff873d1-b334-8b11-c933-771600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff873d1-b334-8b11-c933-771600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff8ce85-0492-9111-f6e9-13cb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff8da28-b334-8b11-c933-7ac600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ff873dd-b334-8b11-c933-773300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8ff9-b334-8b11-c933-889600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8f97-0492-9111-f6e9-22bf00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8f97-0492-9111-f6e9-22bf00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8ff9-b334-8b11-c933-889600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8ff9-b334-8b11-c933-889600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8f97-0492-9111-f6e9-22bf00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc9d87-b334-8b11-c933-892000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffcb47d-0492-9111-f6e9-256c00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc9d87-b334-8b11-c933-892000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8f97-0492-9111-f6e9-22bf00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffcb4bc-0492-9111-f6e9-260800000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5ffc8f97-0492-9111-f6e9-22bf00000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff0f4f-b334-8b03-eb45-abb000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff55da-bd4d-ff11-dda8-f5f100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff4bee-df9a-ce12-1f0c-17ea00000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff55da-bd4d-ff11-dda8-f5f100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff0f4f-b334-8b03-eb45-abb000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff55da-bd4d-ff11-dda8-f5f100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff55da-bd4d-ff11-dda8-f5f100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff55da-bd4d-ff11-dda8-f5f100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff0f4f-b334-8b03-eb45-abb000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fff55da-bd4d-ff11-dda8-f5f100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6000b7ae-fb29-6c12-1a81-98b100000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6000b7ae-fb29-6c12-1a81-98b100000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6000d46c-fb29-6c12-1a81-b20c00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600056a3-f7e5-b011-fce8-97b000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60005709-bd4d-ff11-dda9-0ac100000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6007464b-6e64-6917-17e8-c1f000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60074b49-325c-8a17-9462-387600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60074819-6e64-6917-17e8-d4f000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600741d0-6e64-6912-0a78-785300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600741d0-6e64-6912-0a78-785300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600741d0-6e64-6912-0a78-785300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600741d0-6e64-6912-0a78-785300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60074819-6e64-6917-17e8-d4f000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600741d0-6e64-6912-0a78-785300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6007464b-6e64-6917-17e8-c1f000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60074819-6e64-6917-17e8-d4f000000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6008893b-633a-ab12-1bb8-e0a900000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60088d55-633a-ab12-1bb8-e41a00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6008893b-633a-ab12-1bb8-e0a900000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6008893b-633a-ab12-1bb8-e0a900000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6008893b-633a-ab12-1bb8-e0a900000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600987d7-7d98-3a11-f63c-fa9200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f008f-4329-897e-ac23-7bd800000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f008f-4329-897e-ac23-7bd800000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f008f-4329-897e-ac23-7bd800000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600ed42e-4329-8911-ce45-d1fa00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f41b2-bd19-6811-e68e-a21900000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600ed42e-4329-8911-ce45-d1fa00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f008f-4329-897e-ac23-7bd800000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f008f-4329-897e-ac23-7bd800000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f008f-4329-897e-ac23-7bd800000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f47f0-6fd0-dc17-68a3-4a1200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600f47f0-6fd0-dc17-68a3-4a1200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600ed42e-4329-8911-ce45-d1fa00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(600fb1ac-73c6-0b12-0490-27bb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6011f31e-a4b7-4c18-d3a8-c47600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6011f31e-a4b7-4c18-d3a8-c47600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6011f331-73c6-0b18-04ce-110200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6010bdda-a4b7-4c12-0bd1-9dfb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6011f331-73c6-0b18-04ce-110200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60118bcf-a4b7-4c18-d3a8-c0d700000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6010bdda-a4b7-4c12-0bd1-9dfb00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60118bcf-a4b7-4c18-d3a8-c0d700000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6011f31e-a4b7-4c18-d3a8-c47600000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(6011f331-73c6-0b18-04ce-110200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60132acb-73c6-0b3c-a7f3-ba3200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60132acb-73c6-0b3c-a7f3-ba3200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60145587-6780-4a12-28b2-0d0000000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60145a3c-8423-1211-ce79-6c5d00000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60183090-c8b5-0e11-d845-49c000000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c74-c8b5-0e11-d845-4eff00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c94-c8b5-0e11-d845-4f6b00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c74-c8b5-0e11-d845-4eff00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c74-c8b5-0e11-d845-4eff00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c74-c8b5-0e11-d845-4eff00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c74-c8b5-0e11-d845-4eff00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c74-c8b5-0e11-d845-4eff00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c94-c8b5-0e11-d845-4f6b00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60189c94-c8b5-0e11-d845-4f6b00000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(601c2c05-969c-0b11-f7d0-b09700000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(60229990-b57b-8a12-187f-e9e000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(59c124ba-e4b0-299e-55b0-f33000000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: 'NoneType' object is not subscriptable
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5a43c08f-e4b0-14fd-6b6a-061200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fbc3571-1d96-7d12-22cb-fefc00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fbc3571-1d96-7d12-22cb-fefc00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fc961c3-b8cf-ca11-a077-dd3300000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(5fa41775-898c-7a11-a6bc-ef3e00000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.
#
# Error inserting data into table users: duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (user_id)=(54943462-e4b0-7e68-4157-a53200000000) already exists.

# %%
load_brands_and_cpg('../../0.data/brands.json')
# Out:
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=(HUGGIES) already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=(GOODNITES) already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.
#
# Error inserting data into table brands: duplicate key value violates unique constraint "brands_brand_code_key"
# DETAIL:  Key (brand_code)=() already exists.

# %%
load_receipts_and_items('../../0.data/receipts.json')
# Out:
# /var/folders/dl/nq7zpgs52r382_fm_jd2ygyh0000gn/T/ipykernel_40017/2292210093.py:2: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return datetime.utcfromtimestamp(ms / 1000.0) if ms is not None else None
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5f9c74f7-c88c-1415-cbdd-b83900000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff1e1e9-b6a9-d73a-3a9f-10f600000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff1e1df-cfcf-6c39-9c27-4ab300000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5f9c74e3-f193-7815-bd2c-1d7300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff1e196-cfcf-6c39-9c27-4a3800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff36d78-135e-7011-bcb8-648800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5c3388ca-ea88-e155-13a9-506900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff37124-135e-7011-bcb8-6bc300000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5c3388ca-ea88-e155-13a9-506900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff473f3-c1e2-d012-1a9b-270700000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff4ce68-c1e2-d012-1a9b-302200000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fa5ad37-6a26-f611-e71a-b5ef00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff4ce65-c3d6-3511-e2a4-853b00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff4ce3c-c1e2-d012-1a9b-2fba00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff616a6-8f14-2f11-dd18-916300000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff5d19b-8f14-2f11-dd18-869600000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff73be5-eb7c-7d31-ca8a-45a700000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff7741e-0492-9111-f6e9-090200000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff79459-b334-8b11-c933-736d00000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff75004-b334-8b11-c933-6bd600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff73be9-eb7c-7d31-ca8a-45bc00000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff79460-0492-9111-f6e9-0ceb00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff726a3-8f14-2f11-dd18-95dc00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff8da4e-0492-9111-f6e9-146200000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff8da7c-0492-9111-f6e9-14de00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff8da65-b334-8b11-c933-7b2900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff8da62-b334-8b11-c933-7b2100000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fa5b0b7-20dc-5111-dd86-dcc100000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff8c886-0492-9111-f6e9-13b700000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ff873d3-0492-9111-f6e9-109600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc98b6-0492-9111-f6e9-23f500000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9d8c-b334-8b11-c933-892700000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9da0-b334-8b11-c933-895100000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc8cc1-0492-9111-f6e9-22a300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9da0-b334-8b11-c933-895100000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffcb4b9-b334-8b11-c933-8ae700000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffca2f3-b334-8b11-c933-8a1000000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc92a1-0492-9111-f6e9-23cb00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9da0-b334-8b11-c933-895100000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffcb48d-0492-9111-f6e9-259400000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9da0-b334-8b11-c933-895100000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9d9d-0492-9111-f6e9-244f00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc9d9c-b334-8b11-c933-893f00000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffc8cb3-0492-9111-f6e9-229d00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffcb4b8-b334-8b11-c933-8ae100000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5ffe1154-0492-9101-d0aa-ebb200000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff561a-bd4d-ff11-dda8-fa2b00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff2698-b334-8b03-eb45-bb1000000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fff4c7d-61ff-a811-fdb0-856f00000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b884-fb29-6c12-1a81-ad3b00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5e27526d-0bdb-6a13-8c32-b55600000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5e27526d-0bdb-6a13-8c32-b55600000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000d4aa-fb29-6c12-1a81-b27e00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5e27526d-0bdb-6a13-8c32-b55600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000d4b5-fb29-6c12-1a81-b2bd00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5e56d385-07a0-df22-a15d-fc8500000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b75b-be5f-c96d-fee1-d4d300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b75b-be5f-c96d-fee1-d4d300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b75b-be5f-c96d-fee1-d4d300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b75b-be5f-c96d-fee1-d4d300000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60037329-e257-124e-c6b9-9eeb00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60023de5-fb29-6c12-1a81-b95500000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6002475c-fb29-6c12-1a81-b98d00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60025c65-fb29-6c4e-f805-d9e600000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b75b-be5f-c96d-fee1-d4d300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600258da-fb29-6c4e-f805-d9b700000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6002541a-e257-124e-c6b9-9a3a00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60024f24-e257-124e-c6b9-9a1300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60025c65-fb29-6c4e-f805-d9e600000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60025c65-fb29-6c4e-f805-d9e600000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60037005-e257-124e-c6b9-9ec200000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6002541a-e257-124e-c6b9-9a3a00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6000b75b-be5f-c96d-fee1-d4d300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60025fe0-e257-124e-c6b9-9a8700000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600498c4-e257-124e-c6b9-a33100000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60037a94-fb29-6c4e-f805-ddbe00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6004a5d3-fb29-6c4e-f805-e25600000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600495c3-fb29-6c4e-f805-e1fc00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60049cdc-e257-124e-c6b9-a35300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fb0a078-be5f-c977-5c1f-394500000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6004a965-e257-124e-c6b9-a39f00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fb0a078-be5f-c977-5c1f-394500000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6007423b-6e64-6912-0a78-7c2c00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6006f1c5-e257-127d-5d9a-edfb00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008896c-633a-ab12-1bb8-e11d00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088d5c-b631-0511-daa4-ee6f00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008412f-6e64-697a-bedc-d5d500000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600861d3-be5f-c924-7bab-3e0c00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600887a5-b631-0511-daa4-e9a700000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088d58-633a-ab12-1bb8-e42400000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088d5c-b631-0511-daa4-ee6f00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088838-633a-ab12-1bb8-df6900000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5cd06f1f-2acf-0a26-67da-628b00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600861d3-be5f-c924-7bab-3e0c00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088af5-633a-ab12-1bb8-e31b00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088d5c-b631-0511-daa4-ee6f00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600861d3-be5f-c924-7bab-3e0c00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60088aff-633a-ab12-1bb8-e33d00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008f02f-b631-0511-daa4-f31400000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6009e604-50b3-3111-9438-500900000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008e9cd-b631-0511-daa4-f2e400000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6009f692-7d98-3a12-4e9a-daad00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6009e604-50b3-3111-9438-500900000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600992d1-7d98-3a11-f63d-11ad00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6009e604-50b3-3111-9438-500900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008f02f-b631-0511-daa4-f31400000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60099c14-50b3-3111-fd61-f70200000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60099c14-50b3-3111-fd61-f70200000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008f02f-b631-0511-daa4-f31400000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6009e604-50b3-3111-9438-500900000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6009fd15-50b3-3111-9438-50b100000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6008e9cd-b631-0511-daa4-f2e400000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60099691-50b3-3111-fd61-f6d900000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600b3495-50b3-3111-9438-560000000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600b2d7a-50b3-3111-9438-55cb00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600afb2a-7d98-3a12-4e9a-ded000000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600a1a45-7d98-3a12-4e9a-db9b00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600afb2a-7d98-3a12-4e9a-ded000000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600afb2a-7d98-3a12-4e9a-ded000000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600b41d0-50b3-3111-9438-565500000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600af809-7d98-3a12-4e9a-deb300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600b39ce-50b3-3111-9438-562a00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600b0068-7d98-3a12-4e9a-def900000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600a1ddf-50b3-3111-9438-51a200000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600ba68e-7d98-3a12-4e9a-e1d300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600b477e-7d98-3a12-4e9a-e06100000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600ed950-4329-8911-ce45-e82c00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600f489d-6fd0-dc17-68a3-5a8800000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600f014d-4329-897e-ac23-8b8800000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600f20c1-5edb-787d-ce06-091100000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600f00d0-5edb-787d-ce05-fb8400000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600ed950-4329-8911-ce45-e82c00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600f3501-5edb-7820-98e2-ac1b00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60118bea-a4b7-4c18-d3a8-c0f800000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6010bdf6-73c6-0b12-0490-404e00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6010be18-a4b7-4c12-0bd1-9e4300000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fa8d542-b055-fd1d-fdf0-951700000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6010be1c-73c6-0b12-0490-407900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60118c09-a4b7-4c18-d3a8-c12e00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fa8d573-770b-516d-da4f-4d2100000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6012e1e6-a4b7-4c3c-bc51-608800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(600f29a6-4329-897e-ac23-904900000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60132b88-73c6-0b3c-a7f3-bae800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60144360-8423-1211-ce79-3ced00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60147a84-c8b5-0e11-d845-3f2900000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60145a54-6780-4a12-28b2-0ded00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60145ff3-8423-1211-ce79-6d5100000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60145a51-6780-4a12-28b2-0ddd00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6014554a-6780-4a12-28b2-0ca900000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60145582-8423-1211-ce79-6b8800000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601441a9-8423-1211-ce79-260300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60144354-6780-4a12-28b1-dcaf00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601836c2-c8b5-0e11-d845-4b5800000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60147d2a-c8b5-0e11-d845-3f5300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601830cd-c8b5-0e11-d845-4a6f00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60147d2a-c8b5-0e11-d845-3f5300000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60182f1d-c8b5-0e11-d845-48c400000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60186237-c8b5-0e11-d845-4d5f00000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60189068-9a1b-0912-05b6-1c8700000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60183c83-9a1b-0912-05b6-1aca00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601830ce-9a1b-0912-05b6-18e800000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60182f1d-c8b5-0e11-d845-48c400000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60182f1d-c8b5-0e11-d845-48c400000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601830ce-9a1b-0912-05b6-18e800000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60183682-9a1b-0912-05b6-194d00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60186237-c8b5-0e11-d845-4d5f00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60182f1d-c8b5-0e11-d845-48c400000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601890b2-c8b5-0e11-d845-4e8200000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60147d2a-c8b5-0e11-d845-3f5300000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60189068-9a1b-0912-05b6-1c8700000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60147d2a-c8b5-0e11-d845-3f5300000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60186237-c8b5-0e11-d845-4d5f00000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60186237-c8b5-0e11-d845-4d5f00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60189c92-c8b5-0e11-d845-4f5d00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fb1bd51-9c09-d811-e521-1cef00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60189c90-c8b5-0e11-d845-4f4900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(5fb2da58-2357-ec11-d4ec-c40300000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(542ace60-e4b0-b3d7-2492-249900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601aaebd-e409-2010-2984-9b3c00000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601aaebd-e409-2010-2984-9b3c00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601aaebd-e409-2010-2984-9b3c00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601c68ce-29c3-0a12-27ad-a46800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601ead00-b57b-8a12-187f-ce7800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(601ead00-b57b-8a12-187f-ce7800000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60217687-9940-9b11-fcf8-987f00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(54ca99a9-e4b0-b11b-4f7d-6dc500000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(602401f1-c081-0012-2240-9ad600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60245433-efa6-0112-282c-185900000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(602401f1-c081-0012-2240-9ad600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(6024291f-58b9-8912-1e6b-ad5f00000000) is not present in table "users".
#
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(602401f1-c081-0012-2240-9ad600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(602401f1-c081-0012-2240-9ad600000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60253861-efa6-017a-44dc-6b5000000000) is not present in table "users".
#
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60253861-efa6-017a-44dc-6b5000000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60253861-efa6-017a-44dc-6b5000000000) is not present in table "users".
#
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60253891-b545-9379-5bf6-924200000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60253891-b545-9379-5bf6-924200000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60268c7b-b545-931a-c636-83af00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# Error inserting data into table receipts or receipt_items: insert or update on table "receipts" violates foreign key constraint "receipts_user_id_fkey"
# DETAIL:  Key (user_id)=(60268c78-efa6-011b-b151-077d00000000) is not present in table "users".
#
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
